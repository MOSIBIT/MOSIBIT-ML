# %%
import mediapipe as mp
import os
import csv
import cv2

# %%
# Function to Extract Feature from images or Frame
def extract_feature(input_image):
    mp_hands = mp.solutions.hands
    mp_drawing = mp.solutions.drawing_utils 
    image = cv2.imread(input_image)
    with mp_hands.Hands(static_image_mode=True, max_num_hands=2, min_detection_confidence=0.1) as hands:
        while True:
            results = hands.process(cv2.flip(cv2.cvtColor(image, cv2.COLOR_BGR2RGB), 1))
            image_height, image_width, _ = image.shape
            # Print handedness (left v.s. right hand).
            print(f'Handedness of {input_image}:')
            print(results.multi_handedness)

            # Draw hand landmarks of each hand.
            print(f'Hand landmarks of {input_image}:')
            if not results.multi_hand_landmarks:
                wristX = 0
                wristY = 0

                thumb_CmcX = 0
                thumb_CmcY = 0
                thumb_McpX = 0
                thumb_McpY = 0
                thumb_IpX = 0
                thumb_IpY = 0
                thumb_TipX = 0
                thumb_TipY = 0

                index_McpX = 0
                index_McpY = 0
                index_PipX = 0
                index_PipY = 0
                index_DipX = 0
                index_DipY = 0
                index_TipX = 0
                index_TipY = 0

                middle_McpX = 0
                middle_McpY = 0
                middle_PipX = 0
                middle_PipY = 0
                middle_DipX = 0
                middle_DipY = 0
                middle_TipX = 0
                middle_TipY = 0

                ring_McpX = 0
                ring_McpY = 0
                ring_PipX = 0
                ring_PipY = 0
                ring_DipX = 0
                ring_DipY = 0
                ring_TipX = 0
                ring_TipY = 0

                pinky_McpX = 0
                pinky_McpY = 0
                pinky_PipX = 0
                pinky_PipY = 0
                pinky_DipX = 0
                pinky_DipY = 0
                pinky_TipX = 0
                pinky_TipY = 0


                return (wristX, wristY, 
                        thumb_CmcX, thumb_CmcY, thumb_McpX, thumb_McpY, thumb_IpX, thumb_IpY, thumb_TipX, thumb_TipY,
                        index_McpX, index_McpY, index_PipX, index_PipY, index_DipX, index_DipY, index_TipX, index_TipY,
                        middle_McpX, middle_McpY, middle_PipX, middle_PipY, middle_DipX, middle_DipY, middle_TipX, middle_TipY,
                        ring_McpX, ring_McpY, ring_PipX, ring_PipY, ring_DipX, ring_DipY, ring_TipX, ring_TipY,
                        pinky_McpX, pinky_McpY, pinky_PipX, pinky_PipY, pinky_DipX, pinky_DipY, pinky_TipX, pinky_TipY)
            
            annotated_image = cv2.flip(image.copy(), 1)
            for hand_landmarks in results.multi_hand_landmarks:
                # Wrist Hand /  Pergelangan Tangan
                wristX = hand_landmarks.landmark[mp_hands.HandLandmark.WRIST].x * image_width
                wristY = hand_landmarks.landmark[mp_hands.HandLandmark.WRIST].y * image_height

                # Thumb Finger / Ibu Jari
                thumb_CmcX = hand_landmarks.landmark[mp_hands.HandLandmark.THUMB_CMC].x * image_width
                thumb_CmcY = hand_landmarks.landmark[mp_hands.HandLandmark.THUMB_CMC].y * image_height
                thumb_McpX = hand_landmarks.landmark[mp_hands.HandLandmark.THUMB_MCP].x * image_width
                thumb_McpY = hand_landmarks.landmark[mp_hands.HandLandmark.THUMB_MCP].y * image_height
                thumb_IpX = hand_landmarks.landmark[mp_hands.HandLandmark.THUMB_IP].x * image_width
                thumb_IpY = hand_landmarks.landmark[mp_hands.HandLandmark.THUMB_IP].y * image_height
                thumb_TipX = hand_landmarks.landmark[mp_hands.HandLandmark.THUMB_TIP].x * image_width
                thumb_TipY = hand_landmarks.landmark[mp_hands.HandLandmark.THUMB_TIP].y * image_height

                # Index Finger / Jari Telunjuk
                index_McpX = hand_landmarks.landmark[mp_hands.HandLandmark.INDEX_FINGER_MCP].x * image_width
                index_McpY = hand_landmarks.landmark[mp_hands.HandLandmark.INDEX_FINGER_MCP].y * image_height
                index_PipX = hand_landmarks.landmark[mp_hands.HandLandmark.INDEX_FINGER_PIP].x * image_width
                index_PipY = hand_landmarks.landmark[mp_hands.HandLandmark.INDEX_FINGER_PIP].y * image_height
                index_DipX = hand_landmarks.landmark[mp_hands.HandLandmark.INDEX_FINGER_DIP].x * image_width
                index_DipY = hand_landmarks.landmark[mp_hands.HandLandmark.INDEX_FINGER_DIP].y * image_height
                index_TipX = hand_landmarks.landmark[mp_hands.HandLandmark.INDEX_FINGER_TIP].x * image_width
                index_TipY = hand_landmarks.landmark[mp_hands.HandLandmark.INDEX_FINGER_TIP].y * image_height

                # Middle Finger / Jari Tengah
                middle_McpX = hand_landmarks.landmark[mp_hands.HandLandmark.MIDDLE_FINGER_MCP].x * image_width
                middle_McpY = hand_landmarks.landmark[mp_hands.HandLandmark.MIDDLE_FINGER_MCP].y * image_height
                middle_PipX = hand_landmarks.landmark[mp_hands.HandLandmark.MIDDLE_FINGER_PIP].x * image_width
                middle_PipY = hand_landmarks.landmark[mp_hands.HandLandmark.MIDDLE_FINGER_PIP].y * image_height
                middle_DipX = hand_landmarks.landmark[mp_hands.HandLandmark.MIDDLE_FINGER_DIP].x * image_width
                middle_DipY = hand_landmarks.landmark[mp_hands.HandLandmark.MIDDLE_FINGER_DIP].y * image_height
                middle_TipX = hand_landmarks.landmark[mp_hands.HandLandmark.MIDDLE_FINGER_TIP].x * image_width
                middle_TipY = hand_landmarks.landmark[mp_hands.HandLandmark.MIDDLE_FINGER_TIP].y * image_height

                # Ring Finger / Jari Cincin
                ring_McpX = hand_landmarks.landmark[mp_hands.HandLandmark.RING_FINGER_MCP].x * image_width
                ring_McpY = hand_landmarks.landmark[mp_hands.HandLandmark.RING_FINGER_MCP].y * image_height
                ring_PipX = hand_landmarks.landmark[mp_hands.HandLandmark.RING_FINGER_PIP].x * image_width
                ring_PipY = hand_landmarks.landmark[mp_hands.HandLandmark.RING_FINGER_PIP].y * image_height
                ring_DipX = hand_landmarks.landmark[mp_hands.HandLandmark.RING_FINGER_DIP].x * image_width
                ring_DipY = hand_landmarks.landmark[mp_hands.HandLandmark.RING_FINGER_DIP].y * image_height
                ring_TipX = hand_landmarks.landmark[mp_hands.HandLandmark.RING_FINGER_TIP].x * image_width
                ring_TipY = hand_landmarks.landmark[mp_hands.HandLandmark.RING_FINGER_TIP].y * image_height

                # Pinky Finger / Jari Kelingking
                pinky_McpX = hand_landmarks.landmark[mp_hands.HandLandmark.PINKY_MCP].x * image_width
                pinky_McpY = hand_landmarks.landmark[mp_hands.HandLandmark.PINKY_MCP].y * image_height
                pinky_PipX = hand_landmarks.landmark[mp_hands.HandLandmark.PINKY_PIP].x * image_width
                pinky_PipY = hand_landmarks.landmark[mp_hands.HandLandmark.PINKY_PIP].y * image_height
                pinky_DipX = hand_landmarks.landmark[mp_hands.HandLandmark.PINKY_DIP].x * image_width
                pinky_DipY = hand_landmarks.landmark[mp_hands.HandLandmark.PINKY_DIP].y * image_height
                pinky_TipX = hand_landmarks.landmark[mp_hands.HandLandmark.PINKY_TIP].x * image_width
                pinky_TipY = hand_landmarks.landmark[mp_hands.HandLandmark.PINKY_TIP].y * image_height

                # Draw the Skeleton
                mp_drawing.draw_landmarks(annotated_image, hand_landmarks, mp_hands.HAND_CONNECTIONS)
                
            return (wristX, wristY, 
                    thumb_CmcX, thumb_CmcY, thumb_McpX, thumb_McpY, thumb_IpX, thumb_IpY, thumb_TipX, thumb_TipY,
                    index_McpX, index_McpY, index_PipX, index_PipY, index_DipX, index_DipY, index_TipX, index_TipY,
                    middle_McpX, middle_McpY, middle_PipX, middle_PipY, middle_DipX, middle_DipY, middle_TipX, middle_TipY,
                    ring_McpX, ring_McpY, ring_PipX, ring_PipY, ring_DipX, ring_DipY, ring_TipX, ring_TipY,
                    pinky_McpX, pinky_McpY, pinky_PipX, pinky_PipY, pinky_DipX, pinky_DipY, pinky_TipX, pinky_TipY)

# %%
#Function to create CSV file or add dataset to the existed CSV file
def toCSV(filecsv, class_type, wristX, wristY, 
          thumb_CmcX, thumb_CmcY, thumb_McpX, thumb_McpY, thumb_IpX, thumb_IpY, thumb_TipX, thumb_TipY,
          index_McpX, index_McpY, index_PipX, index_PipY, index_DipX, index_DipY, index_TipX, index_TipY,
          middle_McpX, middle_McpY, middle_PipX, middle_PipY, middle_DipX, middle_DipY, middle_TipX, middle_TipY,
          ring_McpX, ring_McpY, ring_PipX, ring_PipY, ring_DipX, ring_DipY, ring_TipX, ring_TipY,
          pinky_McpX, pinky_McpY, pinky_PipX, pinky_PipY, pinky_DipX, pinky_DipY, pinky_TipX, pinky_TipY):
    if os.path.isfile(filecsv):
        print ("File exist thus shall write append to the file")
        with open(filecsv, 'a+', newline='') as file:
            # Create a writer object from csv module
            writer = csv.writer(file)
            writer.writerow([class_type, wristX, wristY, 
                            thumb_CmcX, thumb_CmcY, thumb_McpX, thumb_McpY, thumb_IpX, thumb_IpY, thumb_TipX, thumb_TipY,
                            index_McpX, index_McpY, index_PipX, index_PipY, index_DipX, index_DipY, index_TipX, index_TipY,
                            middle_McpX, middle_McpY, middle_PipX, middle_PipY, middle_DipX, middle_DipY, middle_TipX, middle_TipY,
                            ring_McpX, ring_McpY, ring_PipX, ring_PipY, ring_DipX, ring_DipY, ring_TipX, ring_TipY,
                            pinky_McpX, pinky_McpY, pinky_PipX, pinky_PipY, pinky_DipX, pinky_DipY, pinky_TipX, pinky_TipY])
    else:
        print ("File not exist thus shall create new file as", filecsv)
        with open(filecsv, 'w', newline='') as file:
            # Create a writer object from csv module
            writer = csv.writer(file)
            writer.writerow(["class_type", "wristX", "wristY", 
                            "thumb_CmcX", "thumb_CmcY", "thumb_McpX", "thumb_McpY", "thumb_IpX", "thumb_IpY", "thumb_TipX", "thumb_TipY",
                            "index_McpX", "index_McpY", "index_PipX", "index_PipY", "index_DipX", "index_DipY", "index_TipX", "index_TipY",
                            "middle_McpX", "middle_McpY", "middle_PipX", "middle_PipY", "middle_DipX", "middle_DipY", "middle_TipX", "middle_TipY",
                            "ring_McpX", "ring_McpY", "ring_PipX", "ring_PipY", "ring_DipX", "ring_DipY", "ring_TipX", "ring_TipY",
                            "pinky_McpX", "pinky_McpY", "pinky_PipX", "pinky_PipY", "pinky_DipX", "pinky_DipY", "pinky_TipX", "pinky_TipY"])
            writer.writerow([class_type, wristX, wristY, 
                            thumb_CmcX, thumb_CmcY, thumb_McpX, thumb_McpY, thumb_IpX, thumb_IpY, thumb_TipX, thumb_TipY,
                            index_McpX, index_McpY, index_PipX, index_PipY, index_DipX, index_DipY, index_TipX, index_TipY,
                            middle_McpX, middle_McpY, middle_PipX, middle_PipY, middle_DipX, middle_DipY, middle_TipX, middle_TipY,
                            ring_McpX, ring_McpY, ring_PipX, ring_PipY, ring_DipX, ring_DipY, ring_TipX, ring_TipY,
                            pinky_McpX, pinky_McpY, pinky_PipX, pinky_PipY, pinky_DipX, pinky_DipY, pinky_TipX, pinky_TipY])

# %%
#Extract Feature for Training
paths = "SIBI_datasets_LEMLITBANG_SIBI_R_90.10_RAW/training/"
csv_path = "hands_SIBI_training.csv"

if os.path.exists(csv_path):
    print("File does exist, going delete before start extraction and replace it with new")
    os.remove(csv_path)
else:
    print("The file does not exist", csv_path, ",Going Create after Extraction")
    
for dirlist in os.listdir(paths):
    for root, directories, filenames in os.walk(os.path.join(paths, dirlist)):
        print("Inside Folder", dirlist, "Consist :")
        for filename in filenames:
            if filename.endswith(".jpg") or filename.endswith(".JPG"):
                print(os.path.join(root, filename), True)
                (wristX, wristY, 
                 thumb_CmcX, thumb_CmcY, thumb_McpX, thumb_McpY, thumb_IpX, thumb_IpY, thumb_TipX, thumb_TipY,
                 index_McpX, index_McpY, index_PipX, index_PipY, index_DipX, index_DipY, index_TipX, index_TipY,
                 middle_McpX, middle_McpY, middle_PipX, middle_PipY, middle_DipX, middle_DipY, middle_TipX, middle_TipY,
                 ring_McpX, ring_McpY, ring_PipX, ring_PipY, ring_DipX, ring_DipY, ring_TipX, ring_TipY,
                 pinky_McpX, pinky_McpY, pinky_PipX, pinky_PipY, pinky_DipX, pinky_DipY, pinky_TipX, pinky_TipY) = extract_feature(os.path.join(root, filename))
                print(wristX, wristY)
                if ((not wristX == 0) and (not wristY == 0)):
                    toCSV(csv_path, dirlist, wristX, wristY, 
                          thumb_CmcX, thumb_CmcY, thumb_McpX, thumb_McpY, thumb_IpX, thumb_IpY, thumb_TipX, thumb_TipY,
                          index_McpX, index_McpY, index_PipX, index_PipY, index_DipX, index_DipY, index_TipX, index_TipY,
                          middle_McpX, middle_McpY, middle_PipX, middle_PipY, middle_DipX, middle_DipY, middle_TipX, middle_TipY,
                          ring_McpX, ring_McpY, ring_PipX, ring_PipY, ring_DipX, ring_DipY, ring_TipX, ring_TipY,
                          pinky_McpX, pinky_McpY, pinky_PipX, pinky_PipY, pinky_DipX, pinky_DipY, pinky_TipX, pinky_TipY)
                else :
                    print("Hand does not have landmarks")
                print("\n")
# Out:
# File does exist, going delete before start extraction and replace it with new
# Inside Folder A Consist :
# SIBI_datasets_LEMLITBANG_SIBI_R_90.10_RAW/training/A\19BD9D4B-8035-4186-8CE1-546DFA9D3369.jpg True
# Handedness of SIBI_datasets_LEMLITBANG_SIBI_R_90.10_RAW/training/A\19BD9D4B-8035-4186-8CE1-546DFA9D3369.jpg:
# [classification {
#   index: 1
#   score: 1.0
#   label: "Right"
# }
# ]
# Hand landmarks of SIBI_datasets_LEMLITBANG_SIBI_R_90.10_RAW/training/A\19BD9D4B-8035-4186-8CE1-546DFA9D3369.jpg:
# 614.6637797355652 905.8066204786301
# File not exist thus shall create new file as hands_SIBI_training.csv
#
#
# SIBI_datasets_LEMLITBANG_SIBI_R_90.10_RAW/training/A\20210607_165156.jpg True
# Handedness of SIBI_datasets_LEMLITBANG_SIBI_R_90.10_RAW/training/A\20210607_165156.jpg:
# [classification {
#   index: 1
#   score: 0.99999964
#   label: "Right"
# }
# ]
# Hand landmarks of SIBI_datasets_LEMLITBANG_SIBI_R_90.10_RAW/training/A\20210607_165156.jpg:
# 1586.3405499458313 1973.9896259307861
# File exist thus shall write append to the file
#
#
# SIBI_datasets_LEMLITBANG_SIBI_R_90.10_RAW/training/A\20210607_165158.jpg True
# Handedness of SIBI_datasets_LEMLITBANG_SIBI_R_90.10_RAW/training/A\20210607_165158.jpg:
# [classification {
#   index: 1
#   score: 0.99999523
#   label: "Right"
# }
# ]
# Hand landmarks of SIBI_datasets_LEMLITBANG_SIBI_R_90.10_RAW/training/A\20210607_165158.jpg:
# 1586.6581506729126 1899.797420501709
# File exist thus shall write append to the file
#
#
# SIBI_datasets_LEMLITBANG_SIBI_R_90.10_RAW/training/A\20210607_165200.jpg True
# Handedness of SIBI_datasets_LEMLITBANG_SIBI_R_90.10_RAW/training/A\20210607_165200.jpg:
# [classification {
#   index: 1
#   score: 0.99999964
#   label: "Right"
# }
# ]
# Hand landmarks of SIBI_datasets_LEMLITBANG_SIBI_R_90.10_RAW/training/A\20210607_165200.jpg:
# 1609.0154914855957 1907.0421257019043
# File exist thus shall write append to the file
#
#
# SIBI_datasets_LEMLITBANG_SIBI_R_90.10_RAW/training/A\20210607_165203.jpg True
# Handedness of SIBI_datasets_LEMLITBANG_SIBI_R_90.10_RAW/training/A\20210607_165203.jpg:
# [classification {
#   index: 1
#   score: 0.99999624
#   label: "Right"
# }
# ]
# Hand landmarks of SIBI_datasets_LEMLITBANG_SIBI_R_90.10_RAW/training/A\20210607_165203.jpg:
# 1650.9914138317108 1806.711464881897
# File exist thus shall write append to the file
#
#
# SIBI_datasets_LEMLITBANG_SIBI_R_90.10_RAW/training/A\3023CE07-DCB2-4111-A803-A1EC6D6E8524.jpg True
# Handedness of SIBI_datasets_LEMLITBANG_SIBI_R_90.10_RAW/training/A\3023CE07-DCB2-4111-A803-A1EC6D6E8524.jpg:
# [classification {
#   index: 1
#   score: 0.99999905
#   label: "Right"
# }
# , classification {
#   index: 0
#   score: 0.9043909
#   label: "Left"
# }
# ]
# Hand landmarks of SIBI_datasets_LEMLITBANG_SIBI_R_90.10_RAW/training/A\3023CE07-DCB2-4111-A803-A1EC6D6E8524.jpg:
# 613.6877685785294 1068.6601852178574
# File exist thus shall write append to the file
#
#
# SIBI_datasets_LEMLITBANG_SIBI_R_90.10_RAW/training/A\A (1).jpg True
# Handedness of SIBI_datasets_LEMLITBANG_SIBI_R_90.10_RAW/training/A\A
IBI_datasets_LEMLITBANG_SIBI_R_90.10_RAW/validation/"
csv_path = "hands_SIBI_validation.csv"

if os.path.exists(csv_path):
    print("File does exist, going delete before start extraction and replace it with new")
    os.remove(csv_path)
else:
    print("The file does not exist", csv_path, ",Going Create after Extraction")
    
for dirlist in os.listdir(paths):
    for root, directories, filenames in os.walk(os.path.join(paths, dirlist)):
        print("Inside Folder", dirlist, "Consist :")
        for filename in filenames:
            if filename.endswith(".jpg") or filename.endswith(".JPG"):
                print(os.path.join(root, filename), True)
                (wristX, wristY, 
                 thumb_CmcX, thumb_CmcY, thumb_McpX, thumb_McpY, thumb_IpX, thumb_IpY, thumb_TipX, thumb_TipY,
                 index_McpX, index_McpY, index_PipX, index_PipY, index_DipX, index_DipY, index_TipX, index_TipY,
                 middle_McpX, middle_McpY, middle_PipX, middle_PipY, middle_DipX, middle_DipY, middle_TipX, middle_TipY,
                 ring_McpX, ring_McpY, ring_PipX, ring_PipY, ring_DipX, ring_DipY, ring_TipX, ring_TipY,
                 pinky_McpX, pinky_McpY, pinky_PipX, pinky_PipY, pinky_DipX, pinky_DipY, pinky_TipX, pinky_TipY) = extract_feature(os.path.join(root, filename))
                print(wristX, wristY)
                if ((not wristX == 0) and (not wristY == 0)):
                    toCSV(csv_path, dirlist, wristX, wristY, 
                          thumb_CmcX, thumb_CmcY, thumb_McpX, thumb_McpY, thumb_IpX, thumb_IpY, thumb_TipX, thumb_TipY,
                          index_McpX, index_McpY, index_PipX, index_PipY, index_DipX, index_DipY, index_TipX, index_TipY,
                          middle_McpX, middle_McpY, middle_PipX, middle_PipY, middle_DipX, middle_DipY, middle_TipX, middle_TipY,
                          ring_McpX, ring_McpY, ring_PipX, ring_PipY, ring_DipX, ring_DipY, ring_TipX, ring_TipY,
                          pinky_McpX, pinky_McpY, pinky_PipX, pinky_PipY, pinky_DipX, pinky_DipY, pinky_TipX, pinky_TipY)
                else :
                    print("Hand does not have landmarks")
                print("\n")
# Out:
# File does exist, going delete before start extraction and replace it with new
# Inside Folder A Consist :
# SIBI_datasets_LEMLITBANG_SIBI_R_90.10_RAW/validation/A\20210607_165207.jpg True
# Handedness of SIBI_datasets_LEMLITBANG_SIBI_R_90.10_RAW/validation/A\20210607_165207.jpg:
# [classification {
#   index: 1
#   score: 0.99995273
#   label: "Right"
# }
# ]
# Hand landmarks of SIBI_datasets_LEMLITBANG_SIBI_R_90.10_RAW/validation/A\20210607_165207.jpg:
# 1595.4751982688904 1713.8828449249268
# File not exist thus shall create new file as hands_SIBI_validation.csv
#
#
# SIBI_datasets_LEMLITBANG_SIBI_R_90.10_RAW/validation/A\A (1).jpg True
# Handedness of SIBI_datasets_LEMLITBANG_SIBI_R_90.10_RAW/validation/A\A (1).jpg:
# [classification {
#   index: 1
#   score: 0.99998367
#   label: "Right"
# }
# ]
# Hand landmarks of SIBI_datasets_LEMLITBANG_SIBI_R_90.10_RAW/validation/A\A (1).jpg:
# 719.0490961074829 1577.5256156921387
# File exist thus shall write append to the file
#
#
# SIBI_datasets_LEMLITBANG_SIBI_R_90.10_RAW/validation/A\A (2).jpg True
# Handedness of SIBI_datasets_LEMLITBANG_SIBI_R_90.10_RAW/validation/A\A (2).jpg:
# [classification {
#   index: 1
#   score: 0.999999
#   label: "Right"
# }
# ]
# Hand landmarks of SIBI_datasets_LEMLITBANG_SIBI_R_90.10_RAW/validation/A\A (2).jpg:
# 757.7804923057556 1601.1055707931519
# File exist thus shall write append to the file
#
#
# SIBI_datasets_LEMLITBANG_SIBI_R_90.10_RAW/validation/A\F0E23C22-677F-4E20-8CF0-E3F3CC2F6E9C.jpg True
# Handedness of SIBI_datasets_LEMLITBANG_SIBI_R_90.10_RAW/validation/A\F0E23C22-677F-4E20-8CF0-E3F3CC2F6E9C.jpg:
# [classification {
#   index: 1
#   score: 0.99999803
#   label: "Right"
# }
# ]
# Hand landmarks of SIBI_datasets_LEMLITBANG_SIBI_R_90.10_RAW/validation/A\F0E23C22-677F-4E20-8CF0-E3F3CC2F6E9C.jpg:
# 615.7606691122055 1031.6984368562698
# File exist thus shall write append to the file
#
#
# SIBI_datasets_LEMLITBANG_SIBI_R_90.10_RAW/validation/A\IMG20210607183143.jpg True
# Handedness of SIBI_datasets_LEMLITBANG_SIBI_R_90.10_RAW/validation/A\IMG20210607183143.jpg:
# [classification {
#   index: 1
#   score: 0.9999927
#   label: "Right"
# }
# , classification {
#   index: 0
#   score: 0.64449745
#   label: "Left"
# }
# ]
# Hand landmarks of SIBI_datasets_LEMLITBANG_SIBI_R_90.10_RAW/validation/A\IMG20210607183143.jpg:
# 322.91058325767517 3155.5546875
# File exist thus shall write append to the file
#
#
# SIBI_datasets_LEMLITBANG_SIBI_R_90.10_RAW/validation/A\IMG_0212.JPG True
# Handedness of SIBI_datasets_LEMLITBANG_SIBI_R_90.10_RAW/validation/A\IMG_0212.JPG:
# [classification {
#   index: 1
#   score: 0.99999994
#   label: "Right"
# }
# ]
# Hand landmarks of SIBI_datasets_LEMLITBANG_SIBI_R_90.10_RAW/validation/A\IMG_0212.JPG:
# 1352.164252281189 1563.1171579360962
# File exist thus shall write append to the file
#
#
# SIBI_datasets_LEMLITBANG_SIBI_R_90.10_RAW/validation/A\IMG_20210605_174842.jpg True
# Handedness of SIBI_datasets_LEMLITBANG_SIBI_R_90.10_RAW/validation/A\IMG_20210605_174842.jpg:
# [classification {
#   index: 1
#   score: 0.99999994
#   label: "Right"
# }
# ]
# Hand landmarks of SIBI_datasets_LEMLITBANG_SIBI_R_90.10_RAW/validation/A\IMG_20210605_174842.jpg:
# 786.0900721549988 2153.4875679016113
# File exist thus shall write append to the file
#
#
# SIBI_datasets_LEMLITBANG_SIBI_R_90.10_RAW/validation/A
#   label: "Right"
# }
# ]
# Hand landmarks of SIBI_datasets_LEMLITBANG_SIBI_R_90.10_RAW/validation/V\IMG_20210606_205105.jpg:
# 2515.657253265381 3046.7857847213745
# File exist thus shall write append to the file
#
#
# SIBI_datasets_LEMLITBANG_SIBI_R_90.10_RAW/validation/V\V (1).jpg True
# Handedness of SIBI_datasets_LEMLITBANG_SIBI_R_90.10_RAW/validation/V\V (1).jpg:
# [classification {
#   index: 1
#   score: 0.99999857
#   label: "Right"
# }
# ]
# Hand landmarks of SIBI_datasets_LEMLITBANG_SIBI_R_90.10_RAW/validation/V\V (1).jpg:
# 846.9046950340271 1667.5419807434082
# File exist thus shall write append to the file
#
#
# SIBI_datasets_LEMLITBANG_SIBI_R_90.10_RAW/validation/V\V (2).jpg True
# Handedness of SIBI_datasets_LEMLITBANG_SIBI_R_90.10_RAW/validation/V\V (2).jpg:
# [classification {
#   index: 1
#   score: 0.96696436
#   label: "Right"
# }
# ]
# Hand landmarks of SIBI_datasets_LEMLITBANG_SIBI_R_90.10_RAW/validation/V\V (2).jpg:
# 915.823221206665 1485.3630065917969
# File exist thus shall write append to the file
#
#
# Inside Folder W Consist :
# SIBI_datasets_LEMLITBANG_SIBI_R_90.10_RAW/validation/W\20210607_175829.jpg True
# Handedness of SIBI_datasets_LEMLITBANG_SIBI_R_90.10_RAW/validation/W\20210607_175829.jpg:
# [classification {
#   index: 1
#   score: 0.9999994
#   label: "Right"
# }
# ]
# Hand landmarks of SIBI_datasets_LEMLITBANG_SIBI_R_90.10_RAW/validation/W\20210607_175829.jpg:
# 1541.5563139915466 2327.2063150405884
# File exist thus shall write append to the file
#
#
# SIBI_datasets_LEMLITBANG_SIBI_R_90.10_RAW/validation/W\20210607_175832.jpg True
# Handedness of SIBI_datasets_LEMLITBANG_SIBI_R_90.10_RAW/validation/W\20210607_175832.jpg:
# [classification {
#   index: 1
#   score: 0.9999998
#   label: "Right"
# }
# ]
# Hand landmarks of SIBI_datasets_LEMLITBANG_SIBI_R_90.10_RAW/validation/W\20210607_175832.jpg:
# 1547.3576517105103 2362.295015335083
# File exist thus shall write append to the file
#
#
# SIBI_datasets_LEMLITBANG_SIBI_R_90.10_RAW/validation/W\FD287999-A783-449C-9C92-98CCC469DA37.jpg True
# Handedness of SIBI_datasets_LEMLITBANG_SIBI_R_90.10_RAW/validation/W\FD287999-A783-449C-9C92-98CCC469DA37.jpg:
# [classification {
#   index: 1
#   score: 1.0
#   label: "Right"
# }
# ]
# Hand landmarks of SIBI_datasets_LEMLITBANG_SIBI_R_90.10_RAW/validation/W\FD287999-A783-449C-9C92-98CCC469DA37.jpg:
# 569.6300715208054 1200.0246150493622
# File exist thus shall write append to the file
#
#
# SIBI_datasets_LEMLITBANG_SIBI_R_90.10_RAW/validation/W\IMG20210607184128_01.jpg True
# Handedness of SIBI_datasets_LEMLITBANG_SIBI_R_90.10_RAW/validation/W\IMG20210607184128_01.jpg:
# [classification {
#   index: 1
#   score: 1.0
#   label: "Right"
# }
# ]
# Hand landmarks of SIBI_datasets_LEMLITBANG_SIBI_R_90.10_RAW/validation/W\IMG20210607184128_01.jpg:
# 1623.2561111450195 2121.202606201172
# File exist thus shall write append to the file
#
#
# SIBI_datasets_LEMLITBANG_SIBI_R_90.10_RAW/validation/W\IMG_0322.JPG True
# Handedness of SIBI_datasets_LEMLITBANG_SIBI_R_90.10_RAW/validation/W\IMG_0322.JPG:
# [classification {
#   index: 1
#   score: 1.0
#   label: "Right"
# }
# ]
# Hand landmarks of SIBI_datasets_LEMLITBANG_SIBI_R_90.10_RAW/validation/W\IMG_0322.JPG:
# 1492.9643239974976 2242.6253337860107
# File exist thus shall write append to the file
#
#
# SIBI_datasets_LEMLITBANG_SIBI_R_90.10_RAW/validation/W\IMG_20210605_174232.jpg True
# Handedness of SIBI_datasets_LEMLITBANG_SIBI_R_90.10_RAW/validation/W\IMG_20210605_174232.jpg:
# [classification {
#   index: 1
#   score: 1.0
#   label: "Right"
# }
# ]
# Hand landmarks of SIBI_datasets_LEMLITBANG_SIBI_R_90.10_RAW/validation/W\IMG_20210605_174232.jpg:
# 1245.6747786998749 2821.9156951904297
# File exist thus shall write append to the file
#
#
# SIBI_datasets_LEMLITBANG_SIBI_R_90.10_RAW/validation/W\IMG_20210606_205110.jpg True
# Handedness of SIBI_datasets_LEMLITBANG_SIBI_R_90.10_RAW/validation/W\IMG_20210606_205110.jpg:
# [classification {
#   index: 1
#   score: 0.99999976
#   label: "Right"
# }
# , classification {
#   index: 1
#   score: 0.97541714
#   label: "Right"
# }
# ]
# Hand landmarks of SIBI_datasets_LEMLITBANG_SIBI_R_90.10_RAW/validation/W\IMG_20210606_205110.jpg:
# 2643.462166786194 2751.7036151885986
# File exist thus shall write append to the file
#
#
# SIBI_datasets_LEMLITBANG_SIBI_R_90.10_RAW/validation/W\W (1).jpg True
# Handedness of SIBI_datasets_LEMLITBANG_SIBI_R_90.10_RAW/validation/W\W (1).jpg:
# [classification {
#   index: 1
#   score: 0.99999976
#   label: "Right"
# }
# ]
# Hand landmarks of SIBI_datasets_LEMLITBANG_SIBI_R_90.10_RAW/validation/W\W (1).jpg:
# 867.3987984657288 1558.1622123718262
# File exist thus shall write append to the file
#
#
# SIBI_datasets_LEMLITBANG_SIBI_R_90.10_RAW/validation/W\W (2).jpg True
# Handedness of SIBI_datasets_LEMLITBANG_SIBI_R_90.10_RAW/validation/W\W (2).jpg:
# [classification {
#   index: 1
#   score: 1.0
#   label: "Right"
# }
# ]
# Hand landmarks of SIBI_datasets_LEMLITBANG_SIBI_R_90.10_RAW/validation/W\W (2).jpg:
# 897.9968428611755 1631.8703889846802
# File exist thus shall write append to the file
#
#
# Inside Folder X Consist :
# SIBI_datasets_LEMLITBANG_SIBI_R_90.10_RAW/validation/X\20210607_175923.jpg True
# Handedness of SIBI_datasets_LEMLITBANG_SIBI_R_90.10_RAW/validation/X\20210607_175923.jpg:
# [classification {
#   index: 1
#   score: 0.98465526
#   label: "Right"
# }
# ]
# Hand landmarks of SIBI_datasets_LEMLITBANG_SIBI_R_90.10_RAW/validation/X\20210607_175923.jpg:
# 1092.6646513938904 2651.788730621338
# File exist thus shall write append to the file
#
#
# SIBI_datasets_LEMLITBANG_SIBI_R_90.10_RAW/validation/X\D387A9E7-6E91-447D-95C5-637E45855DFD.jpg True
# Handedness of SIBI_datasets_LEMLITBANG_SIBI_R_90.10_RAW/validation/X\D387A9E7-6E91-447D-95C5-637E45855DFD.jpg:
# [classification {
#   index: 1
#   score: 0.99871194
#   label: "Right"
# }
# ]
# Hand landmarks of SIBI_datasets_LEMLITBANG_SIBI_R_90.10_RAW/validation/X\D387A9E7-6E91-447D-95C5-637E45855DFD.jpg:
# 677.824079990387 994.4183995723724
# File exist thus shall write append to the file
#
#
# SIBI_datasets_LEMLITBANG_SIBI_R_90.10_RAW/validation/X\IMG20210607184140.jpg True
# Handedness of SIBI_datasets_LEMLITBANG_SIBI_R_90.10_RAW/validation/X\IMG20210607184140.jpg:
# [classification {
#   index: 1
#   score: 0.99999917
#   label: "Right"
# }
# ]
# Hand landmarks of SIBI_datasets_LEMLITBANG_SIBI_R_90.10_RAW/validation/X\IMG20210607184140.jpg:
# 1656.8884029388428 1693.7196350097656
# File exist thus shall write append to the file
#
#
# SIBI_datasets_LEMLITBANG_SIBI_R_90.10_RAW/validation/X\IMG_0327.JPG True
# Handedness of SIBI_datasets_LEMLITBANG_SIBI_R_90.10_RAW/validation/X\IMG_0327.JPG:
# [classification {
#   index: 1
#   score: 0.9688196
#   label: "Right"
# }
# ]
# Hand landmarks of SIBI_datasets_LEMLITBANG_SIBI_R_90.10_RAW/validation/X\IMG_0327.JPG:
# 794.6875727176666 1786.0853052139282
# File exist thus shall write append to the file
#
#
# SIBI_datasets_LEMLITBANG_SIBI_R_90.10_RAW/validation/X\IMG_20210605_174320.jpg True
# Handedness of SIBI_datasets_LEMLITBANG_SIBI_R_90.10_RAW/validation/X\IMG_20210605_174320.jpg:
# [classification {
#   index: 1
#   score: 1.0
#   label: "Right"
# }
# ]
# Hand landmarks of SIBI_datasets_LEMLITBANG_SIBI_R_90.10_RAW/validation/X\IMG_20210605_174320.jpg:
# 995.6030230522156 2476.778160095215
# File exist thus shall write append to the file
#
#
# SIBI_datasets_LEMLITBANG_SIBI_R_90.10_RAW/validation/X\IMG_20210606_205116.jpg True
# Handedness of SIBI_datasets_LEMLITBANG_SIBI_R_90.10_RAW/validation/X\IMG_20210606_205116.jpg:
# [classification {
#   index: 1
#   score: 1.0
#   label: "Right"
# }
# ]
# Hand landmarks of SIBI_datasets_LEMLITBANG_SIBI_R_90.10_RAW/validation/X\IMG_20210606_205116.jpg:
# 2540.4356145858765 2885.541474342346
# File exist thus shall write append to the file
#
#
# SIBI_datasets_LEMLITBANG_SIBI_R_90.10_RAW/validation/X\X (1).jpg True
# Handedness of SIBI_datasets_LEMLITBANG_SIBI_R_90.10_RAW/validation/X\X (1).jpg:
# [classification {
#   index: 1
#   score: 0.9960645
#   label: "Right"
# }
# ]
# Hand landmarks of SIBI_datasets_LEMLITBANG_SIBI_R_90.10_RAW/validation/X\X (1).jpg:
# 541.6830778121948 1123.712182044983
# File exist thus shall write append to the file
#
#
# SIBI_datasets_LEMLITBANG_SIBI_R_90.10_RAW/validation/X\X (2).jpg True
# Handedness of SIBI_datasets_LEMLITBANG_SIBI_R_90.10_RAW/validation/X\X (2).jpg:
# [classification {
#   index: 1
#   score: 0.9999645
#   label: "Right"
# }
# ]
# Hand landmarks of SIBI_datasets_LEMLITBANG_SIBI_R_90.10_RAW/validation/X\X (2).jpg:
# 557.1184754371643 1219.0680503845215
# File exist thus shall write append to the file
#
#
# Inside Folder Y Consist :
# SIBI_datasets_LEMLITBANG_SIBI_R_90.10_RAW/validation/Y\20210607_180001.jpg True
# Handedness of SIBI_datasets_LEMLITBANG_SIBI_R_90.10_RAW/validation/Y\20210607_180001.jpg:
# [classification {
#   index: 1
#   score: 0.9999997
#   label: "Right"
# }
# ]
# Hand landmarks of SIBI_datasets_LEMLITBANG_SIBI_R_90.10_RAW/validation/Y\20210607_180001.jpg:
# 1570.5218918323517 2292.8415632247925
# File exist thus shall write append to the file
#
#
# SIBI_datasets_LEMLITBANG_SIBI_R_90.10_RAW/validation/Y\F96A5429-8A16-417F-8991-8F325C1492D7.jpg True
# Handedness of SIBI_datasets_LEMLITBANG_SIBI_R_90.10_RAW/validation/Y\F96A5429-8A16-417F-8991-8F325C1492D7.jpg:
# [classification {
#   index: 1
#   score: 1.0
#   label: "Right"
# }
# ]
# Hand landmarks of SIBI_datasets_LEMLITBANG_SIBI_R_90.10_RAW/validation/Y\F96A5429-8A16-417F-8991-8F325C1492D7.jpg:
# 630.3463876247406 956.2501270771027
# File exist thus shall write append to the file
#
#
# SIBI_datasets_LEMLITBANG_SIBI_R_90.10_RAW/validation/Y\IMG20210607184235.jpg True
# Handedness of SIBI_datasets_LEMLITBANG_SIBI_R_90.10_RAW/validation/Y\IMG20210607184235.jpg:
# [classification {
#   index: 1
#   score: 0.99998367
#   label: "Right"
# }
# ]
# Hand landmarks of SIBI_datasets_LEMLITBANG_SIBI_R_90.10_RAW/validation/Y\IMG20210607184235.jpg:
# 1866.19011592865 1759.3856048583984
# File exist thus shall write append to the file
#
#
# SIBI_datasets_LEMLITBANG_SIBI_R_90.10_RAW/validation/Y\IMG_0332.JPG True
# Handedness of SIBI_datasets_LEMLITBANG_SIBI_R_90.10_RAW/validation/Y\IMG_0332.JPG:
# [classification {
#   index: 1
#   score: 0.9999983
#   label: "Right"
# }
# ]
# Hand landmarks of SIBI_datasets_LEMLITBANG_SIBI_R_90.10_RAW/validation/Y\IMG_0332.JPG:
# 1359.3982479572296 1786.874355316162
# File exist thus shall write append to the file
#
#
# SIBI_datasets_LEMLITBANG_SIBI_R_90.10_RAW/validation/Y\IMG_20210605_174410.jpg True
# Handedness of SIBI_datasets_LEMLITBANG_SIBI_R_90.10_RAW/validation/Y\IMG_20210605_174410.jpg:
# [classification {
#   index: 1
#   score: 0.99999994
#   label: "Right"
# }
# ]
# Hand landmarks of SIBI_datasets_LEMLITBANG_SIBI_R_90.10_RAW/validation/Y\IMG_20210605_174410.jpg:
# 1127.2197768688202 1942.5509033203125
# File exist thus shall write append to the file
#
#
# SIBI_datasets_LEMLITBANG_SIBI_R_90.10_RAW/validation/Y\IMG_20210606_203426.jpg True
# Handedness of SIBI_datasets_LEMLITBANG_SIBI_R_90.10_RAW/validation/Y\IMG_20210606_203426.jpg:
# [classification {
#   index: 1
#   score: 0.8711914
#   label: "Right"
# }
# ]
# Hand landmarks of SIBI_datasets_LEMLITBANG_SIBI_R_90.10_RAW/validation/Y\IMG_20210606_203426.jpg:
# 2144.8445320129395 2151.3518686294556
# File exist thus shall write append to the file
#
#
# SIBI_datasets_LEMLITBANG_SIBI_R_90.10_RAW/validation/Y\Y (1).jpg True
# Handedness of SIBI_datasets_LEMLITBANG_SIBI_R_90.10_RAW/validation/Y\Y (1).jpg:
# [classification {
#   index: 1
#   score: 0.99999815
#   label: "Right"
# }
# ]
# Hand landmarks of SIBI_datasets_LEMLITBANG_SIBI_R_90.10_RAW/validation/Y\Y (1).jpg:
# 1094.6632623672485 1466.0850763320923
# File exist thus shall write append to the file
#
#
# SIBI_datasets_LEMLITBANG_SIBI_R_90.10_RAW/validation/Y\Y (2).jpg True
# Handedness of SIBI_datasets_LEMLITBANG_SIBI_R_90.10_RAW/validation/Y\Y (2).jpg:
# [classification {
#   index: 1
#   score: 0.9999998
#   label: "Right"
# }
# ]
# Hand landmarks of SIBI_datasets_LEMLITBANG_SIBI_R_90.10_RAW/validation/Y\Y (2).jpg:
# 1137.3471021652222 1596.731424331665
# File exist thus shall write append to the file
#
#
# Inside Folder Z Consist :
# SIBI_datasets_LEMLITBANG_SIBI_R_90.10_RAW/validation/Z\20210607_180212.jpg True
# Handedness of SIBI_datasets_LEMLITBANG_SIBI_R_90.10_RAW/validation/Z\20210607_180212.jpg:
# [classification {
#   index: 1
#   score: 1.0
#   label: "Right"
# }
# ]
# Hand landmarks of SIBI_datasets_LEMLITBANG_SIBI_R_90.10_RAW/validation/Z\20210607_180212.jpg:
# 1142.7844183444977 2196.8601207733154
# File exist thus shall write append to the file
#
#
# SIBI_datasets_LEMLITBANG_SIBI_R_90.10_RAW/validation/Z\FF8667B3-841F-4B45-82AB-04F09DA64C1E.jpg True
# Handedness of SIBI_datasets_LEMLITBANG_SIBI_R_90.10_RAW/validation/Z\FF8667B3-841F-4B45-82AB-04F09DA64C1E.jpg:
# None
# Hand landmarks of SIBI_datasets_LEMLITBANG_SIBI_R_90.10_RAW/validation/Z\FF8667B3-841F-4B45-82AB-04F09DA64C1E.jpg:
# 0 0
# Hand does not have landmarks
#
#
# SIBI_datasets_LEMLITBANG_SIBI_R_90.10_RAW/validation/Z\IMG_0337.JPG True
# Handedness of SIBI_datasets_LEMLITBANG_SIBI_R_90.10_RAW/validation/Z\IMG_0337.JPG:
# [classification {
#   index: 1
#   score: 0.99999744
#   label: "Right"
# }
# ]
# Hand landmarks of SIBI_datasets_LEMLITBANG_SIBI_R_90.10_RAW/validation/Z\IMG_0337.JPG:
# 720.0040150880814 1708.27965259552
# File exist thus shall write append to the file
#
#
# SIBI_datasets_LEMLITBANG_SIBI_R_90.10_RAW/validation/Z\IMG_20210605_174501.jpg True
# Handedness of SIBI_datasets_LEMLITBANG_SIBI_R_90.10_RAW/validation/Z\IMG_20210605_174501.jpg:
# [classification {
#   index: 1
#   score: 0.99999887
#   label: "Right"
# }
# ]
# Hand landmarks of SIBI_datasets_LEMLITBANG_SIBI_R_90.10_RAW/validation/Z\IMG_20210605_174501.jpg:
# 758.0305598974228 2493.725372314453
# File exist thus shall write append to the file
#
#
# SIBI_datasets_LEMLITBANG_SIBI_R_90.10_RAW/validation/Z\IMG_20210606_205123.jpg True
# Handedness of SIBI_datasets_LEMLITBANG_SIBI_R_90.10_RAW/validation/Z\IMG_20210606_205123.jpg:
# [classification {
#   index: 1
#   score: 1.0
#   label: "Right"
# }
# ]
# Hand landmarks of SIBI_datasets_LEMLITBANG_SIBI_R_90.10_RAW/validation/Z\IMG_20210606_205123.jpg:
# 2576.749849319458 2868.969536781311
# File exist thus shall write append to the file
#
#
# SIBI_datasets_LEMLITBANG_SIBI_R_90.10_RAW/validation/Z\IMG_20210607_203123.jpg True
# Handedness of SIBI_datasets_LEMLITBANG_SIBI_R_90.10_RAW/validation/Z\IMG_20210607_203123.jpg:
# [classification {
#   index: 1
#   score: 0.9999958
#   label: "Right"
# }
# ]
# Hand landmarks of SIBI_datasets_LEMLITBANG_SIBI_R_90.10_RAW/validation/Z\IMG_20210607_203123.jpg:
# 1902.5471849441528 2725.740898132324
# File exist thus shall write append to the file
#
#
# SIBI_datasets_LEMLITBANG_SIBI_R_90.10_RAW/validation/Z\Z (1).jpg True
# Handedness of SIBI_datasets_LEMLITBANG_SIBI_R_90.10_RAW/validation/Z\Z (1).jpg:
# [classification {
#   index: 1
#   score: 0.9999956
#   label: "Right"
# }
# ]
# Hand landmarks of SIBI_datasets_LEMLITBANG_SIBI_R_90.10_RAW/validation/Z\Z (1).jpg:
# 646.8257904052734 1212.1690511703491
# File exist thus shall write append to the file
#
#
# SIBI_datasets_LEMLITBANG_SIBI_R_90.10_RAW/validation/Z\Z (2).jpg True
# Handedness of SIBI_datasets_LEMLITBANG_SIBI_R_90.10_RAW/validation/Z\Z (2).jpg:
# [classification {
#   index: 1
#   score: 0.9999983
#   label: "Right"
# }
# ]
# Hand landmarks of SIBI_datasets_LEMLITBANG_SIBI_R_90.10_RAW/validation/Z\Z (2).jpg:
# 742.7935600280762 1290.448784828186
# File exist thus shall write append to the file
